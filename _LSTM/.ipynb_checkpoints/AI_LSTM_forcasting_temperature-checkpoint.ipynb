# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('File1.csv')

# %%
df
# Out:
#      urutan       bulan          data      rata2
# 0         0  1983-01-01  54598.367107  29.673026
# 1         1  1983-02-01  54663.252209  29.708289
# 2         2  1983-03-01  55475.812933  30.149898
# 3         3  1983-04-01  55155.629024  29.975885
# 4         4  1983-05-01  53593.976395  29.127161
# ..      ...         ...           ...        ...
# 403     403  2016-08-01  56240.606407  30.565547
# 404     404  2016-09-01  56647.585022  30.786731
# 405     405  2016-10-01  56401.566578  30.653025
# 406     406  2016-11-01  54655.972265  29.704333
# 407     407  2016-12-01  53373.651503  29.007419
#
# [408 rows x 4 columns]

# %%
df=df.drop(columns=['urutan','rata2'])

# %%
df.bulan = pd.to_datetime(df.bulan)
df = df.set_index("bulan")
data_ = df[:-48]
df=df[:-60]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-b8829bb3f650> in <module>
# ----> 1 df.bulan = pd.to_datetime(df.bulan)
#       2 df = df.set_index("bulan")
#       3 data_ = df[:-48]
#       4 df=df[:-60]
#
# c:\users\cmmac\miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'bulan'

# %%
train, test = df[:-12], df[-12:]

# %%
test
# Out:
#                     data
# bulan
# 2011-01-01  53383.553333
# 2011-02-01  54448.821884
# 2011-03-01  54605.942356
# 2011-04-01  54671.303606
# 2011-05-01  55088.278383
# 2011-06-01  54427.702154
# 2011-07-01  54512.308691
# 2011-08-01  55491.552910
# 2011-09-01  56272.064661
# 2011-10-01  57656.119730
# 2011-11-01  55193.612081
# 2011-12-01  54530.663734

# %%
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(generator,epochs=90)
# Out:
# Epoch 1/90
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0649
# Epoch 2/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0423
# Epoch 3/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0404
# Epoch 4/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0386
# Epoch 5/90
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0345
# Epoch 6/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0293
# Epoch 7/90
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0301
# Epoch 8/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0378: 0s - loss: 0.
# Epoch 9/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0276
# Epoch 10/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0281
# Epoch 11/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0312
# Epoch 12/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0294
# Epoch 13/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0267
# Epoch 14/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0274
# Epoch 15/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0294
# Epoch 16/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0251
# Epoch 17/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0259
# Epoch 18/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0310
# Epoch 19/90
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0246
# Epoch 20/90
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0251
# Epoch 21/90
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0248
# Epoch 22/90
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0277
# Epoch 23/90
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0243
# Epoch 24/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0258
# Epoch 25/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0252
# Epoch 26/90
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0264
# Epoch 27/90
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0248
# Epoch 28/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0231
# Epoch 29/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0261
# Epoch 30/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0239
# Epoch 31/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0240
# Epoch 32/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0248
# Epoch 33/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0246
# Epoch 34/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0229
# Epoch 35/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0233
# Epoch 36/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0235
# Epoch 37/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0228
# Epoch 38/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0228
# Epoch 39/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0236
# Epoch 40/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0231
# Epoch 41/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0256
# Epoch 42/90
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0242
# Epoch 43/90
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0229
# Epoch 44/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0225
# Epoch 45/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0229
# Epoch 46/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0233
# Epoch 47/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0241
# Epoch 48/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0223
# Epoch 49/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0223
# Epoch 50/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0225
# Epoch 51/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0223
# Epoch 52/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0209
# Epoch 53/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0226
# Epoch 54/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0226
# Epoch 55/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0217
# Epoch 56/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0211
# Epoch 57/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0219
# Epoch 58/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0221
# Epoch 59/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0195
# Epoch 60/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0205
# Epoch 61/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0234
# Epoch 62/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0184
# Epoch 63/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0210
# Epoch 64/90
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0204
# Epoch 65/90
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0200
# Epoch 66/90
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0207
# Epoch 67/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0217
# Epoch 68/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0209
# Epoch 69/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0198
# Epoch 70/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0214
# Epoch 71/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0192
# Epoch 72/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0190
# Epoch 73/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0187
# Epoch 74/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0192
# Epoch 75/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0190
# Epoch 76/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0188
# Epoch 77/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0198
# Epoch 78/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0189
# Epoch 79/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0207
# Epoch 80/90
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0182
# Epoch 81/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0194
# Epoch 82/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0181
# Epoch 83/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0183
# Epoch 84/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0184
# Epoch 85/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0189
# Epoch 86/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0179
# Epoch 87/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0176
# Epoch 88/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0170
# Epoch 89/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0166
# Epoch 90/90
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0189

# %%
pred_list = []

batch = train[-12:].reshape((1, n_input, n_features))
batch
# Out:
# array([[[0.38012915],
#         [0.5483801 ],
#         [0.50489878],
#         [0.41936715],
#         [0.45588481],
#         [0.32697692],
#         [0.21720558],
#         [0.44224287],
#         [0.6872416 ],
#         [0.69752001],
#         [0.45849662],
#         [0.        ]]])

# %%
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

pred_list
# Out:
# [array([0.1887435], dtype=float32),
#  array([0.3365223], dtype=float32),
#  array([0.43946636], dtype=float32),
#  array([0.44898278], dtype=float32),
#  array([0.39292583], dtype=float32),
#  array([0.28192577], dtype=float32),
#  array([0.25643337], dtype=float32),
#  array([0.45994925], dtype=float32),
#  array([0.62741417], dtype=float32),
#  array([0.7173656], dtype=float32),
#  array([0.4865704], dtype=float32),
#  array([0.31689912], dtype=float32)]

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=df[-n_input:].index, columns=['Prediction'])

df_test = pd.concat([df,df_predict], axis=1)

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test['data'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
pred_actual_rmse = rmse(df_test.iloc[-n_input:, [0]], df_test.iloc[-n_input:, [1]])
print("rmse: ", pred_actual_rmse)
# Out:
# rmse:  [1420.06456525]

# %%
train = df

# %%
scaler.fit(train)
train = scaler.transform(train)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model.fit_generator(generator,epochs=90)
# Out:
# Epoch 1/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0177
# Epoch 2/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0177
# Epoch 3/90
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0184
# Epoch 4/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0170
# Epoch 5/90
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0161
# Epoch 6/90
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0178
# Epoch 7/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0170
# Epoch 8/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0155
# Epoch 9/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0158
# Epoch 10/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0178
# Epoch 11/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0163
# Epoch 12/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0164
# Epoch 13/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0153
# Epoch 14/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0161
# Epoch 15/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0159
# Epoch 16/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0165
# Epoch 17/90
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0161
# Epoch 18/90
# 56/56 [==============================] - 1s 16ms/step - loss: 0.0158
# Epoch 19/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0173
# Epoch 20/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0172
# Epoch 21/90
# 56/56 [==============================] - 1s 14ms/step - loss: 0.0158
# Epoch 22/90
# 56/56 [==============================] - 1s 15ms/step - loss: 0.0142
# Epoch 23/90
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0168
# Epoch 24/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0151
# Epoch 25/90
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0148
# Epoch 26/90
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0146
# Epoch 27/90
# 56/56 [==============================] - 1s 15ms/step - loss: 0.0155
# Epoch 28/90
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0147
# Epoch 29/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0149
# Epoch 30/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 31/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0163
# Epoch 32/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 33/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 34/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0140
# Epoch 35/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0165
# Epoch 36/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0160
# Epoch 37/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 38/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0153
# Epoch 39/90
# 56/56 [==============================] - 1s 14ms/step - loss: 0.0143
# Epoch 40/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0142
# Epoch 41/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0153
# Epoch 42/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0153
# Epoch 43/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0152
# Epoch 44/90
# 56/56 [==============================] - 1s 14ms/step - loss: 0.0140
# Epoch 45/90
# 56/56 [==============================] - 1s 14ms/step - loss: 0.0134
# Epoch 46/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0135
# Epoch 47/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0136
# Epoch 48/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0138
# Epoch 49/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0131
# Epoch 50/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0140
# Epoch 51/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0134
# Epoch 52/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0139
# Epoch 53/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0134
# Epoch 54/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0137
# Epoch 55/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0129
# Epoch 56/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0130
# Epoch 57/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0139
# Epoch 58/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0136
# Epoch 59/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0133
# Epoch 60/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0146
# Epoch 61/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 62/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0128
# Epoch 63/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0128
# Epoch 64/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0137
# Epoch 65/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0132
# Epoch 66/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0136
# Epoch 67/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0126
# Epoch 68/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0128
# Epoch 69/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0129
# Epoch 70/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0126
# Epoch 71/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0119
# Epoch 72/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0122
# Epoch 73/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0128
# Epoch 74/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0121
# Epoch 75/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0142
# Epoch 76/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0117
# Epoch 77/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0120
# Epoch 78/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0126
# Epoch 79/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0137
# Epoch 80/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0125
# Epoch 81/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0120
# Epoch 82/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0123
# Epoch 83/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0114
# Epoch 84/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0129
# Epoch 85/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0118
# Epoch 86/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0110
# Epoch 87/90
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0126: 0s - loss
# Epoch 88/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0126
# Epoch 89/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0115
# Epoch 90/90
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0118

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
from pandas.tseries.offsets import DateOffset
add_dates = [df.index[-1] + DateOffset(months=x) for x in range(0,13) ]
future_dates = pd.DataFrame(index=add_dates[1:],columns=df.columns)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=future_dates[-n_input:].index, columns=['Prediction'])

df_proj = pd.concat([df,df_predict], axis=1)

# %%
df_asli = df1
plt.figure(figsize=(20, 5))
plt.plot(df_proj.index, df_proj['data'])
plt.plot(df_asli.index, df_asli['data'])
plt.plot(df_proj.index, df_proj['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.
